# %%
# !wget https://github.com/MohamedElashri/ROOT/releases/download/ubuntu/root_v6.28.04_Ubuntu_20.04.zip
# !unzip /content/root_v6.28.04_Ubuntu_20.04.zip
# !apt-get install git dpkg-dev cmake g++ gcc binutils libx11-dev libxpm-dev libxft-dev libxext-dev tar gfortran subversion
# !apt-get inatall libpython3.6-dev
# !rm -f root_v6.28.04_Ubuntu_20.04.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: root_build/tutorials/gui/Slider3Demo.C
#   inflating: root_build/tutorials/gui/mditestbg.xpm
#   inflating: root_build/tutorials/gui/textEntries.C
#   inflating: root_build/tutorials/gui/ntupleTableTest.C
#   inflating: root_build/tutorials/gui/customContextMenu.C
#   inflating: root_build/tutorials/gui/splitterHorizontal.C
#   inflating: root_build/tutorials/gui/guiWithCINT.C
#   inflating: root_build/tutorials/gui/CPUMeter.C
#   inflating: root_build/tutorials/gui/numberEntry.C
#   inflating: root_build/tutorials/gui/splitbuttonTest.C
#   inflating: root_build/tutorials/gui/buttonTest.C
#   inflating: root_build/tutorials/gui/simpleTableTest.C
#   inflating: root_build/tutorials/gui/drag_and_drop.C
#   inflating: root_build/tutorials/gui/textviewostream.C
#   inflating: root_build/tutorials/gui/listBox.C
#   inflating: root_build/tutorials/gui/gtreeTableTest.C
#   inflating: root_build/tutorials/gui/staffTableTest.C
# ...

# %% [markdown]
# The following is needed because colab upgraded the openssl library

# %%
# !wget http://archive.ubuntu.com/ubuntu/pool/main/o/openssl/libssl1.1_1.1.1f-1ubuntu2_amd64.deb
# !sudo dpkg -i libssl1.1_1.1.1f-1ubuntu2_amd64.deb
# !rm -f libssl1.1_1.1.1f-1ubuntu2_amd64.deb
# Out:
# --2024-05-15 09:04:16--  http://archive.ubuntu.com/ubuntu/pool/main/o/openssl/libssl1.1_1.1.1f-1ubuntu2_amd64.deb
# Resolving archive.ubuntu.com (archive.ubuntu.com)... 185.125.190.36, 91.189.91.83, 91.189.91.81, ...
# Connecting to archive.ubuntu.com (archive.ubuntu.com)|185.125.190.36|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1318204 (1.3M) [application/x-debian-package]
# Saving to: ‘libssl1.1_1.1.1f-1ubuntu2_amd64.deb’
#
# libssl1.1_1.1.1f-1u 100%[===================>]   1.26M   397KB/s    in 3.2s
#
# 2024-05-15 09:04:20 (397 KB/s) - ‘libssl1.1_1.1.1f-1ubuntu2_amd64.deb’ saved [1318204/1318204]
#
# Selecting previously unselected package libssl1.1:amd64.
# (Reading database ... 122068 files and directories currently installed.)
# Preparing to unpack libssl1.1_1.1.1f-1ubuntu2_amd64.deb ...
# Unpacking libssl1.1:amd64 (1.1.1f-1ubuntu2) ...
# Setting up libssl1.1:amd64 (1.1.1f-1ubuntu2) ...
# debconf: unable to initialize frontend: Dialog
# ...

# %%
import sys
sys.path.append("/content/root_build/")
sys.path.append("/content/root_build/bin/")
sys.path.append("/content/root_build/include/")
sys.path.append("/content/root_build/lib/")
import ctypes
ctypes.cdll.LoadLibrary('/content/root_build/lib//libCore.so')
ctypes.cdll.LoadLibrary('/content/root_build/lib//libThread.so')
ctypes.cdll.LoadLibrary('/content/root_build/lib//libTreePlayer.so')
# Out:
# <CDLL '/content/root_build/lib//libTreePlayer.so', handle 5ba180cc4170 at 0x7dd4b708a590>

# %%
import pandas as pd
import ROOT

def load_and_process_data(csv_file_path):
    # Read data from CSV
    data = pd.read_csv(csv_file_path)

    # Setup canvas to plot histograms
    canvas = ROOT.TCanvas("canvas", "Particle Landau Fits", 1800, 600)
    canvas.Divide(3, 1)  # Divide canvas into three pads for three histograms

    # Columns to process
    particles = ['q_normalized_pions', 'q_normalized_kaons', 'q_normalized_protons']

    # Loop through each particle type and fit a Landau distribution


    for i, particle in enumerate(particles, start=1):

        print(f"Particle {particle}:")

        # Create a histogram for each particle type
        #histogram = ROOT.TH1F(f"{particle}_hist", f"{particle} Distribution; {particle}; Entries", 100, 100, 2000)

        histogram = ROOT.TH1F(f"{particle}_hist", f"{particle} Distribution; {particle}; Entries", 100, data[particle].min(), 2000)
        for value in data[particle].dropna():
            if (value > 150) & (value<2000):
                histogram.Fill(value)

        # Fit the histogram with a Landau distribution
        fit_result = histogram.Fit("landau", "S")



        # Draw the histogram with the fit superimposed in each pad
        canvas.cd(i)
        histogram.Draw()

        # Optionally print out the fit parameters
        fit_parameters = fit_result.GetParams()
        print(f"Fit Parameters for {particle}:", fit_parameters)

    # Save the canvas to a file
    canvas.SaveAs("landau_fit_comparison.png")

    from IPython.display import Image
    Image(filename='landau_fit_comparison.png')
    display(Image(filename='landau_fit_comparison.png'))


if __name__ == "__main__":
    csv_file_path = "/content/q_normalized_data.csv"
    load_and_process_data(csv_file_path)
#/content/q_normalized_data.csv
# Out:
# Particle q_normalized_pions:
# Fit Parameters for q_normalized_pions: <cppyy.LowLevelView object at 0x7dd46f17cea0>
# Particle q_normalized_kaons:
# Fit Parameters for q_normalized_kaons: <cppyy.LowLevelView object at 0x7dd46f17c500>
# Particle q_normalized_protons:
# Fit Parameters for q_normalized_protons: <cppyy.LowLevelView object at 0x7dd46f17cea0>
#  FCN=740.572 FROM MIGRAD    STATUS=CONVERGED     118 CALLS         119 TOTAL
#                      EDM=7.19363e-09    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     3.79164e+03   3.45192e+01   6.51810e-02   2.81951e-06
#    2  MPV          3.99627e+02   2.35625e+00  -4.99329e-03  -7.47956e-06
#    3  Sigma        1.37301e+02   1.15319e+00   3.37486e-06   1.25986e-01
#  FCN=672.865 FROM MIGRAD    STATUS=CONVERGED     116 CALLS         117 TOTAL
# ...

# %%
from scipy.stats import gaussian_kde

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ROOT

def bootstrap_kde_ci(data, charge_range, n_bootstrap=200):
    bootstrap_probabilities = []
    for i in range(n_bootstrap):
        sample = np.random.choice(data, size=len(data), replace=True)
        kde = gaussian_kde(sample)
        bootstrap_probabilities.append(kde(charge_range))
    lower_bounds = np.percentile(bootstrap_probabilities, 2.5, axis=0)
    upper_bounds = np.percentile(bootstrap_probabilities, 97.5, axis=0)
    return lower_bounds, upper_bounds

import matplotlib.pyplot as plt

def plot_probabilities_with_ci(charge_range, pion_ci, kaon_ci):
    plt.figure(figsize=(10, 6))

    # Plotting the mean probabilities
    plt.plot(charge_range, pion_ci[0], label='Probability of being a Pion', color='blue', linewidth=2)
    plt.plot(charge_range, kaon_ci[0], label='Probability of being a Kaon', color='orange', linewidth=2)

    # Plotting the confidence intervals with noticeable fill
    plt.fill_between(charge_range, pion_ci[1], pion_ci[2], color='blue', alpha=0.2, label='Pion 95% CI')
    plt.fill_between(charge_range, kaon_ci[1], kaon_ci[2], color='orange', alpha=0.2, label='Kaon 95% CI')

    plt.title('Probability of being a Pion or Kaon with 95% Confidence Intervals')
    plt.xlabel('Q Normalized')
    plt.ylabel('Probability')
    plt.legend()
    plt.grid(True)
    plt.show()



def load_and_process_data(csv_file_path):
    # Read data from CSV
    data = pd.read_csv(csv_file_path)

    # Setup figure for matplotlib
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    # Columns to process
    particles = ['q_normalized_pions', 'q_normalized_kaons', 'q_normalized_protons']
    particles = ['q_normalized_pions', 'q_normalized_kaons']

    # Loop through each particle type
    for i, particle in enumerate(particles):
        # Filter and setup data within specified range
        valid_data = data[particle].dropna()
        filtered_data = valid_data[(valid_data > 150) & (valid_data < 2000)]

        # Create a ROOT histogram to fit
        histogram = ROOT.TH1F(f"{particle}_hist", f"{particle} Distribution; {particle}; Entries", 100, 150, 2000)
        for value in filtered_data:
            histogram.Fill(value)

        # Fit the histogram with a Landau distribution using ROOT
        fit_result = histogram.Fit("landau", "S")

        # Extract histogram data to numpy arrays for plotting
        x = np.array([histogram.GetBinCenter(bin) for bin in range(1, histogram.GetNbinsX()+1)])
        y = np.array([histogram.GetBinContent(bin) for bin in range(1, histogram.GetNbinsX()+1)])
        axes[i].bar(x, y, align='center', alpha=0.7, color='b', width=histogram.GetBinWidth(1))

        # Plot fit results using the ROOT TF1
        fit_function = histogram.GetFunction("landau")
        x_fit = np.linspace(150, 2000, 400)
        y_fit = np.array([fit_function.Eval(val) for val in x_fit])
        axes[i].plot(x_fit, y_fit, 'r-', label=f"Landau Fit for {particle}")

        # Set titles and labels
        axes[i].set_title(f"{particle} Distribution with Landau Fit")
        axes[i].set_xlabel(f"{particle}")
        axes[i].set_ylabel("Entries")

        # Print fit parameters
        fit_parameters = fit_result.GetParams()
        mpv = fit_parameters[1]  # Most probable value (MPV)
        sigma = fit_parameters[2]  # Sigma of the Landau distribution
        print(f"Fit Parameters for {particle}: MPV={mpv:.2f}, Sigma={sigma:.2f}")

        # Labeling fit results in the plot
        axes[i].legend([f"Landau Fit\nMPV={mpv:.2f}\nSigma={sigma:.2f}"])

    # Filter and setup data within specified range for Pions and Kaons
    pions_data = data['q_normalized_pions'].dropna()
    pions_data = pions_data[(pions_data > 150) & (pions_data < 2000)]

    kaons_data = data['q_normalized_kaons'].dropna()
    kaons_data = kaons_data[(kaons_data > 150) & (kaons_data < 2000)]

    # Fit Kernel Density Estimates for each particle's charge distribution
    pions_kde = gaussian_kde(pions_data)
    kaons_kde = gaussian_kde(kaons_data)
    query_charge = 200

    # Evaluate the densities at the query charge
    pion_density = pions_kde(query_charge)
    kaon_density = kaons_kde(query_charge)

    # Assuming equal priors for pions and kaons
    prior_pion = 0.5
    prior_kaon = 0.5


    from scipy.stats import ks_2samp

    # Perform Kolmogorov-Smirnov test
    ks_stat, ks_pvalue = ks_2samp(pions_data, kaons_data)
    print(f"KS statistic: {ks_stat:.3f}, p-value: {ks_pvalue:.130f}")

    # Interpretation of results
    if ks_pvalue < 0.05:
        print("Distributions are statistically different.")
    else:
        print("No statistical difference between the distributions.")

    # Layout adjustments and show plot
    plt.tight_layout()
    plt.show()

    # Calculate the posterior probabilities using Bayes' Theorem
    # P(pion|charge) = (P(charge|pion) * P(pion)) / (P(charge|pion) * P(pion) + P(charge|kaon) * P(kaon))
    total_probability = pion_density * prior_pion + kaon_density * prior_kaon
    pion_posterior = (pion_density * prior_pion) / total_probability
    kaon_posterior = (kaon_density * prior_kaon) / total_probability


    print(f"Probability of being a Pion given charge {query_charge}: {pion_posterior[0]:.2f}")
    print(f"Probability of being a Kaon given charge {query_charge}: {kaon_posterior[0]:.2f}")

    # Plotting for visualization
    x = np.linspace(min(pions_data.min(), kaons_data.min()), max(pions_data.max(), kaons_data.max()), 1000)
    plt.figure(figsize=(10, 6))
    plt.plot(x, pions_kde(x), label='Pion KDE')
    plt.plot(x, kaons_kde(x), label='Kaon KDE')
    plt.axvline(x=query_charge, color='r', linestyle='--', label=f'Query Charge: {query_charge}')
    plt.legend()
    plt.title('KDE of Q Normalized for Pions and Kaons')
    plt.xlabel('Q Normalized')
    plt.ylabel('Density')
    plt.show()


    # Range of charge values for probability calculation
    charge_range = np.linspace(150, 2000, 500)
    pion_probabilities = []
    kaon_probabilities = []

    # Calculate the probabilities over the charge range
    for charge in charge_range:
        pion_density = pions_kde(charge)
        kaon_density = kaons_kde(charge)
        total_probability = pion_density * prior_pion + kaon_density * prior_kaon
        pion_probability = (pion_density * prior_pion) / total_probability
        kaon_probability = (kaon_density * prior_kaon) / total_probability
        pion_probabilities.append(pion_probability)
        kaon_probabilities.append(kaon_probability)

    # Plotting the probabilities as functions of charge
    plt.figure(figsize=(10, 6))
    plt.plot(charge_range, pion_probabilities, label='Probability of being a Pion', color='blue')
    plt.plot(charge_range, kaon_probabilities, label='Probability of being a Kaon', color='orange')
    plt.title('Probability of being a Pion or Kaon as a function of Q Normalized')
    plt.xlabel('Q Normalized')
    plt.ylabel('Probability')
    plt.legend()
    plt.grid(True)
    plt.show()


    #### bootstrap .::

    # Bootstrap for confidence intervals
    pion_lower, pion_upper = bootstrap_kde_ci(pions_data, charge_range)
    kaon_lower, kaon_upper = bootstrap_kde_ci(kaons_data, charge_range)

    plt.figure(figsize=(10, 6))
    plt.fill_between(charge_range, pion_lower, pion_upper, color='blue', alpha=0.3, label='Pion 95% CI')
    plt.fill_between(charge_range, kaon_lower, kaon_upper, color='orange', alpha=0.3, label='Kaon 95% CI')
    plt.plot(charge_range, pion_probabilities, label='Probability of being a Pion', color='blue')
    plt.plot(charge_range, kaon_probabilities, label='Probability of being a Kaon', color='orange')
    plt.title('Probability of being a Pion or Kaon with Confidence Intervals')
    plt.xlabel('Q Normalized')
    plt.ylabel('Probability')
    plt.ylim(0.45, 0.55)
    plt.legend()
    plt.grid(True)
    plt.show()

    import numpy as np
    from scipy import stats

    # Proportions of pions and kaons in the range
    pion_proportion = pion_counts[0] / pion_counts.sum()
    kaon_proportion = kaon_counts[0] / kaon_counts.sum()

    # Hypothesis test for difference in proportions
    count_array = np.array([pion_counts, kaon_counts])
    stat, p_value = stats.chi2_contingency(count_array, correction=False)[:2]  # Using a Chi-squared test for simplicity

    # Confidence Interval for the difference in proportions
    # Standard error approach
    def proportion_confidence_interval(count1, n1, count2, n2):
        p1 = count1 / n1
        p2 = count2 / n2
        var = (p1 * (1 - p1) / n1) + (p2 * (1 - p2) / n2)
        se = np.sqrt(var)
        z = 1.96  # For 95% confidence
        diff = p1 - p2
        ci_lower = diff - z * se
        ci_upper = diff + z * se
        return (ci_lower, ci_upper)


    # Output results
    print("Proportion of Pions in range:", pion_proportion)
    print("Proportion of Kaons in range:", kaon_proportion)
    print("P-value for hypothesis test (Pion > Kaon):", p_value)
    print("95% Confidence Interval for difference in proportions:", diff_ci)


if __name__ == "__main__":
    csv_file_path = "/content/q_normalized_data.csv"
    load_and_process_data(csv_file_path)
# Out:
# Fit Parameters for q_normalized_pions: MPV=399.68, Sigma=137.28
# Fit Parameters for q_normalized_kaons: MPV=367.30, Sigma=126.42
# KS statistic: 0.049, p-value: 0.0000000000000000000000000013388842188133819621098316998695337612535127553528878970898460145907347658769670495360060158418491482735
# Distributions are statistically different.
# Probability of being a Pion given charge 200: 0.46
# Probability of being a Kaon given charge 200: 0.54
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-45f3545eb9ac> in <cell line: 199>()
#     199 if __name__ == "__main__":
#     200     csv_file_path = "/content/q_normalized_data.csv"
# --> 201     load_and_process_data(csv_file_path)
#
# <ipython-input-46-45f3545eb9ac> in load_and_process_data(csv_file_path)
#     195
#     196
# --> 197     plot_probabilities_with_ci(charge_range, pion_ci, kaon_ci)
#     198
# ...
